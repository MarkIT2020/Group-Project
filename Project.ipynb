# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
sb.set() 
labData = pd.read_csv('cardio_train.csv',sep=";")
#import os
labData.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
height = pd.DataFrame(labData['height'])
weight = pd.DataFrame(labData['weight'])
ap_hi = pd.DataFrame(labData['ap_hi'])
ap_lo = pd.DataFrame(labData['ap_lo'])

numDF = pd.DataFrame(labData[["height", "weight"]])
sb.pairplot(data = numDF)

# %%
#Problem 2 a

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

#Quality
Quality_train, Quality_test, Alcohol_train, Alcohol_test = train_test_split(Quality, Alcohol, test_size = 0.25)
linreg = LinearRegression()
linreg.fit(Quality_train, Alcohol_train)
print('Quality:')
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
regline_x = Quality_train
regline_y = linreg.intercept_ + linreg.coef_ * regline_x
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(Quality_train, Alcohol_train)
plt.plot(regline_x.to_numpy(), regline_y.to_numpy(), 'r-', linewidth = 3)
plt.show()

#Density
Density_train, Density_test, Alcohol_train, Alcohol_test = train_test_split(Density, Alcohol, test_size = 0.25)
linreg = LinearRegression()
linreg.fit(Density_train, Alcohol_train)
print('Density:')
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
regline_x = Density_train
regline_y = linreg.intercept_ + linreg.coef_ * regline_x
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(Density_train, Alcohol_train)
plt.plot(regline_x.to_numpy(), regline_y.to_numpy(), 'r-', linewidth = 3)
plt.show()


#Acidity
Acidity_train, Acidity_test, Alcohol_train, Alcohol_test = train_test_split(Acidity, Alcohol, test_size = 0.25)
linreg = LinearRegression()
linreg.fit(Acidity_train, Alcohol_train)
print('Acidity:')
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
regline_x = Acidity_train
regline_y = linreg.intercept_ + linreg.coef_ * regline_x
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(Acidity_train, Alcohol_train)
plt.plot(regline_x.to_numpy(), regline_y.to_numpy(), 'r-', linewidth = 3)
plt.show()
# Out:
# Quality:
# Intercept 	: b =  [6.79464557]
# Coefficients 	: a =  [[0.59585543]]
# Density:
# Intercept 	: b =  [279.52761312]
# Coefficients 	: a =  [[-269.97997506]]
# Acidity:
# Intercept 	: b =  [5.26948955]
# Coefficients 	: a =  [[1.55907996]]

# %%
#Problem 2 b
#quality
linreg.fit(Quality_test, Alcohol_test)
Alcohol_test_pred = linreg.predict(Quality_test)
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(Quality_test, Alcohol_test, color = "green")
plt.scatter(Quality_test, Alcohol_test_pred, color = "red")
print('Quality:')
plt.show()
print("Explained Variance of quality (R^2) \t:", linreg.score(Quality_test, Alcohol_test))
def mean_sq_err(actual, predicted):
    return np.mean(np.square(np.array(actual) - np.array(predicted)))
mse = mean_sq_err(Alcohol_test, Alcohol_test_pred)
print("Mean Squared Error (MSE) \t:", mse)
print("\n")

#density
linreg.fit(Density_test, Alcohol_test)
Alcohol_test_pred = linreg.predict(Density_test)
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(Density_test, Alcohol_test, color = "green")
plt.scatter(Density_test, Alcohol_test_pred, color = "red")
print('Density:')
plt.show()
print("Explained Variance of density (R^2) \t:", linreg.score(Density_test, Alcohol_test))
def mean_sq_err(actual, predicted):
    return np.mean(np.square(np.array(actual) - np.array(predicted)))
mse = mean_sq_err(Alcohol_test, Alcohol_test_pred)
print("Mean Squared Error (MSE) \t:", mse)
print("\n")

#acidity
linreg.fit(Acidity_test, Alcohol_test)
Alcohol_test_pred = linreg.predict(Acidity_test)
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(Acidity_test, Alcohol_test, color = "green")
plt.scatter(Acidity_test, Alcohol_test_pred, color = "red")
print('Acidity:')
plt.show()
print("Explained Variance of acidity (R^2) \t:", linreg.score(Acidity_train, Alcohol_train))
def mean_sq_err(actual, predicted):
    return np.mean(np.square(np.array(actual) - np.array(predicted)))
mse = mean_sq_err(Alcohol_test, Alcohol_test_pred)
print("Mean Squared Error (MSE) \t:", mse)
print("\n")
# Out:
# Quality:
# Explained Variance of quality (R^2) 	: 0.0034915507627715225
# Mean Squared Error (MSE) 	: 1.2016617962223994
#
#
# Density:
# Explained Variance of density (R^2) 	: 0.007600492069556819
# Mean Squared Error (MSE) 	: 1.1967069382931332
#
#
# Acidity:
# Explained Variance of acidity (R^2) 	: -0.004844139531032576
# Mean Squared Error (MSE) 	: 1.2056701248413042

# %%
#Problem 2 c
#Quality is best in terms of predicting alcohol. According to the statistics, the explained variance for density
#is lowest for alcolol, around 0.003.

# %%
#Problem 3 a & b
#numDF = pd.DataFrame(labData[["Quality", "Density", "Acidity", "Alcohol"]])

Predictor = pd.DataFrame(labData[['Quality','Density','Acidity']])
Alcohol = pd.DataFrame(labData['Alcohol'])
Predictor_train, Predictor_test, Alcohol_train, Alcohol_test = train_test_split(Predictor, Alcohol, test_size = 0.25)
linreg = LinearRegression()
linreg.fit(Predictor_train, Alcohol_train)

# Predict SalePrice values corresponding to GrLivArea
Alcohol_train_pred = linreg.predict(Predictor_train)
Alcohol_test_pred = linreg.predict(Predictor_test)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(Alcohol_train, Alcohol_train_pred, color = "blue")
axes[0].plot(Alcohol_train.to_numpy(), Alcohol_train.to_numpy(), 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")

axes[1].scatter(Alcohol_test, Alcohol_test_pred, color = "green")
axes[1].plot(Alcohol_test.to_numpy(), Alcohol_test.to_numpy(), 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# %%
#Problem 3 a & b

print("Explained Variance (R^2) on Train Set \t:", linreg.score(Predictor_train, Alcohol_train))
def mean_sq_err(actual, predicted):
    return np.mean(np.square(np.array(actual) - np.array(predicted)))
mse = mean_sq_err(Alcohol_test, Alcohol_test_pred)
print("Mean Squared Error (MSE) \t:", mse)
print("\n")

print("Explained Variance (R^2) on Test Set \t:", linreg.score(Predictor_test, Alcohol_test))
def mean_sq_err(actual, predicted):
    return np.mean(np.square(np.array(actual) - np.array(predicted)))
mse = mean_sq_err(Alcohol_test, Alcohol_test_pred)
print("Mean Squared Error (MSE) \t:", mse)
print("\n")
# Out:
# Explained Variance (R^2) on Train Set 	: 0.35824738525514266
# Mean Squared Error (MSE) 	: 0.6639011111882707
#
#
# Explained Variance (R^2) on Test Set 	: 0.449443205370363
# Mean Squared Error (MSE) 	: 0.6639011111882707
